# %%
import torch
import numpy as np
import pandas as pd

from solution import Solution, draw_metrics
from zoo_params import zoo_params, create_name

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **На huggingFace искал модель, которая хорошо обучена на поиск ответа в тексте, которая занимает мало места и быстро работает на cpu. (Спойлер: у меня это получилось. Финальная модель ест меньше 4гб оперативки и работает очень быстро на ryzen 3600)**
#
# **В итоге нашел такую https://huggingface.co/Den4ikAI/rubert-tiny-squad**
#
# **Она уже неплохо справлялась с задачей, если задавать ей вопрос так "Какое обеспечение исполнения контракта?"**
#
# **Только надо было чуть-чуть обучить ее выдавать не только ответ, но и немного контекста**
#
# **Сначала я попытался обучить только последний слой. Получились неплохие результаты для baseline**

# %%
index = 0
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.45)
# Out:
# start accuracy = 0.7518939393939394
# end accuracy = 0.5359848484848485
# accuracy = 0.48295454545454547
# count of blocks = 0
# hid_size = 312
# only blocks are trained
# start lr = 0.001
# sheduler = ReduceLROnPlateau

# %% [markdown]
# **Далее я решил разморозить encoder**

# %%
index = 1
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.8996212121212122
# end accuracy = 0.7537878787878788
# accuracy = 0.7159090909090909
# count of blocks = 0
# hid_size = 312
# trained encoder and blocks
# start lr = 0.001
# sheduler = ReduceLROnPlateau

# %% [markdown]
# **Далее я стал добавлять линейные блоки в конец модели**

# %%
index = 2
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.8598484848484849
# end accuracy = 0.7537878787878788
# accuracy = 0.7045454545454546
# count of blocks = 1
# hid_size = 312
# trained encoder and blocks
# start lr = 0.001
# sheduler = ReduceLROnPlateau

# %%
index = 3
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.8996212121212122
# end accuracy = 0.7329545454545454
# accuracy = 0.696969696969697
# count of blocks = 3
# hid_size = 312
# trained encoder and blocks
# start lr = 0.001
# sheduler = ReduceLROnPlateau

# %% [markdown]
# **Решил я поэксперементировать с sheduler-ом и заметил, что качество модели сильно растет при маленьком lr**

# %%
index = 4
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9090909090909091
# end accuracy = 0.7689393939393939
# accuracy = 0.7386363636363636
# count of blocks = 3
# hid_size = 312
# trained encoder and blocks
# start lr = 0.001
# sheduler = warmup

# %% [markdown]
# **Уменьшил стартовый lr и получил отличные результаты**

# %%
index = 5
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9375
# end accuracy = 0.8143939393939394
# accuracy = 0.7821969696969697
# count of blocks = 3
# hid_size = 312
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %% [markdown]
# **Далее я пробую разные параметры модели**

# %%
index = 6
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9393939393939394
# end accuracy = 0.8049242424242424
# accuracy = 0.7746212121212122
# count of blocks = 2
# hid_size = 312
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %%
index = 7
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9356060606060606
# end accuracy = 0.8068181818181818
# accuracy = 0.7765151515151515
# count of blocks = 1
# hid_size = 312
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %%
index = 8
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9375
# end accuracy = 0.8106060606060606
# accuracy = 0.7840909090909091
# count of blocks = 3
# hid_size = 512
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %%
index = 9
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9337121212121212
# end accuracy = 0.8068181818181818
# accuracy = 0.7784090909090909
# count of blocks = 4
# hid_size = 512
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %%
index = 10
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9356060606060606
# end accuracy = 0.8068181818181818
# accuracy = 0.7746212121212122
# count of blocks = 5
# hid_size = 512
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %%
index = 11
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9356060606060606
# end accuracy = 0.8200757575757576
# accuracy = 0.7897727272727273
# count of blocks = 3
# hid_size = 1024
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %%
index = 12
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9318181818181818
# end accuracy = 0.8068181818181818
# accuracy = 0.7784090909090909
# count of blocks = 3
# hid_size = 1600
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %%
index = 13
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9299242424242424
# end accuracy = 0.8068181818181818
# accuracy = 0.7727272727272727
# count of blocks = 1
# hid_size = 512
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %%
index = 14
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
draw_metrics(sol, 0.65)
# Out:
# start accuracy = 0.9356060606060606
# end accuracy = 0.8181818181818182
# accuracy = 0.7840909090909091
# count of blocks = 2
# hid_size = 512
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %% [markdown]
# **Пришел к выводу, что лучшая по accuracy - это модель под индексом 11**

# %%
index = 11
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
sol
# Out:
# start accuracy = 0.9356060606060606
# end accuracy = 0.8200757575757576
# accuracy = 0.7897727272727273
# count of blocks = 3
# hid_size = 1024
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %% [markdown]
# **Лучшая по start:accuracy**

# %%
index = 8
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
sol
# Out:
# start accuracy = 0.9375
# end accuracy = 0.8106060606060606
# accuracy = 0.7840909090909091
# count of blocks = 3
# hid_size = 512
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau

# %% [markdown]
# **Лучшая по end:accuracy**

# %%
index = 11
sol = Solution.from_file("sol", f"{create_name(zoo_params[index])}.pkl")
sol
# Out:
# start accuracy = 0.9356060606060606
# end accuracy = 0.8200757575757576
# accuracy = 0.7897727272727273
# count of blocks = 3
# hid_size = 1024
# trained encoder and blocks
# start lr = 0.0001
# sheduler = ReduceLROnPlateau
